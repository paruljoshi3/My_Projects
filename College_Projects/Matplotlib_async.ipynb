# %% [markdown]
# # Visualization with Matplotlib

# %% [markdown]
# ## Importing Matplotlib

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt # pyplot is the interface we use to plot

# %%
plt.style.available # shows all available styles of interface
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('classic')

# %%
# %matplotlib inline
import numpy as np
x = np.linspace(0, 10, 100)

fig=plt.figure()
plt.plot(x,np.sin(x),'-')
plt.plot(x,np.cos(x),'--')

# %%
plt.style.use('seaborn-darkgrid') # it changes entire background to dark

# %%
# %matplotlib inline
import numpy as np
x = np.linspace(0, 10, 100)

fig=plt.figure()
plt.plot(x,np.sin(x),'-')
plt.plot(x,np.cos(x),'--')

# %%
plt.style.use('dark_background')

# %%
# %matplotlib inline
import numpy as np
x = np.linspace(0, 10, 100)

fig=plt.figure()
plt.plot(x,np.sin(x),'-')
plt.plot(x,np.cos(x),'--')

# %%
plt.style.use('classic')

# %%
# %matplotlib notebook
import numpy as np
x = np.linspace(0, 10, 100)

fig=plt.figure()
plt.plot(x,np.sin(x),'-')
plt.plot(x,np.cos(x),'--')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Saving Figures to File

# %%
fig.savefig('my_figure.png') # current working directory

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %%
plt.figure() # create a plot figure

# create the first of two panels and set current axis
plt.subplot(2,1,1) # (rows,columns,panel numbers)
plt.plot(x,np.sin(x))

# create the second panel and set current axis
plt.subplot(2,1,2)
plt.plot(x,np.cos(x));
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure() # create a plot figure

# create the first of two panels and set current axis
plt.subplot(2,2,1) # (rows,columns,panel numbers)
plt.plot(x,np.sin(x))

# create the second panel and set current axis
plt.subplot(2,2,2)
plt.plot(x,np.cos(x))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure() # create a plot figure

# create the first of two panels and set current axis
plt.subplot(2,2,1) # (rows,columns,panel numbers)
plt.plot(x,np.sin(x))

# create the second panel and set current axis
plt.subplot(2,2,2)
plt.plot(x,np.cos(x))

plt.subplot(2,2,3)
plt.plot(x,np.cos(x));
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Simple Line Plots

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
fig = plt.figure()

x = np.linspace(0,10,1000)
plt.plot(x,np.sin(x))

# %%
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x));

# %%
# %matplotlib notebook
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x))
plt.plot(x,np.tan(x))
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# # Adjusting the Plot: Line Colors and Styles

# %%
# %matplotlib inline
plt.plot(x,np.sin(x-0),color='blue') # specify color by name
plt.plot(x,np.sin(x-1),color='g') # short color code(rgbcmyk)
plt.plot(x,np.sin(x-2),color='0.75') # grayscale between 0 to 1
plt.plot(x,np.sin(x-3),color='#FFDD44') # Hex code (RRGGBB from 00 to FF)
plt.plot(x,np.sin(x-4),color=(1.0,0.2,0.3)) # RGB tuple, values 0 to 1
plt.plot(x,np.sin(x-5),color='chartreuse') # all HTMl color names supported

# %%
plt.plot(x, x+0, linestyle='solid')
plt.plot(x, x+1, linestyle='dashed')
plt.plot(x, x+2, linestyle='dashdot')
plt.plot(x, x+3, linestyle='dotted')

# For short, use the following codes:
plt.plot(x, x+4, linestyle='-') # solid
plt.plot(x, x+5, linestyle='--') # dashed
plt.plot(x, x+6, linestyle='-.') # dashdot
plt.plot(x, x+7, linestyle=':') # dotted

# %% [markdown]
# # Scatter Plots

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')

# %%
import pandas as pd

# %%
# Import a dataset using pandas and store a dataframe
data=pd.read_csv("C:/Users/SOURAV SAHA/SOURAV SAHA 21122060.csv")

# %%
data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 506  0.98765   0.0  12.50     0  0.561  6.980  89.0  2.0980    3  320
# 507  0.23456   0.0  12.50     0  0.561  6.980  76.0  2.6540    3  320
# 508  0.44433   0.0  12.50     0  0.561  6.123  98.0  2.9870    3  320
# 509  0.77763   0.0  12.70     0  0.561  6.222  34.0  2.5430    3  329
# 510  0.65432   0.0  12.80     0  0.561  6.760  67.0  2.9870    3  345
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
x=data.CRIM
x
# Out:
# 0      0.00632
# 1      0.02731
# 2      0.02729
# 3      0.03237
# 4      0.06905
#         ...
# 506    0.98765
# 507    0.23456
# 508    0.44433
# 509    0.77763
# 510    0.65432
# Name: CRIM, Length: 511, dtype: float64

# %%
y=data.NOX
y
# Out:
# 0      0.538
# 1      0.469
# 2      0.469
# 3      0.458
# 4      0.458
#        ...
# 506    0.561
# 507    0.561
# 508    0.561
# 509    0.561
# 510    0.561
# Name: NOX, Length: 511, dtype: float64

# %%
plt.plot(x,y,color='black')

# %%
plt.plot(x,y,'o',color='black');

# %%
plt.plot(x,y,'-o',color='black');

# %%
plt.plot(x,y,'-p',color='gray',
        markersize=15, linewidth=4,
        markerfacecolor='white',
        markeredgecolor='gray',
        markeredgewidth=2)

# %% [markdown]
# # Scatter Plots with plt.scatter

# %%
plt.scatter(x,y)

# %%
plt.scatter(x,y,marker='o')

# %%
plt.scatter(x,y,marker='p')
