# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
ad = pd.read_excel (r'D:\adult.xlsx')

# %%
ad
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                   car_name
# 0            70       1  chevrolet chevelle malibu
# 1            70       1          buick skylark 320
# 2            70       1         plymouth satellite
# 3            70       1              amc rebel sst
# 4            70       1                ford torino
# ..          ...     ...                        ...
# 393          82       1            ford mustang gl
# 394          82       2                  vw pickup
# 395          82       1              dodge rampage
# 396          82       1                ford ranger
# 397          82       1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
ad.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model_year        int64
# origin            int64
# car_name         object
# dtype: object

# %%
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car_name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
ad.shape
# Out:
# (398, 9)

# %%
ad.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model_year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
ad.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# car_name        0
# dtype: int64

# %%
ad.horsepower.unique()
# Out:
# array([130, 165, 150, 140, 198, 220, 215, 225, 190, 170, 160, 95, 97, 85,
#        88, 46, 87, 90, 113, 200, 210, 193, '?', 100, 105, 175, 153, 180,
#        110, 72, 86, 70, 76, 65, 69, 60, 80, 54, 208, 155, 112, 92, 145,
#        137, 158, 167, 94, 107, 230, 49, 75, 91, 122, 67, 83, 78, 52, 61,
#        93, 148, 129, 96, 71, 98, 115, 53, 81, 79, 120, 152, 102, 108, 68,
#        58, 149, 89, 63, 48, 66, 139, 103, 125, 133, 138, 135, 142, 77, 62,
#        132, 84, 64, 74, 116, 82], dtype=object)

# %%
ad = ad[ad.horsepower != '?']

# %%
ad.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model_year        int64
# origin            int64
# car_name         object
# dtype: object

# %%
ad.horsepower = ad.horsepower.astype('float')
ad.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin            int64
# car_name         object
# dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#checking the correlation 
ad.cor=ad.corr()
ad.cor
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.777618     -0.805127   -0.778427 -0.832244
# cylinders    -0.777618   1.000000      0.950823    0.842983  0.897527
# displacement -0.805127   0.950823      1.000000    0.897257  0.932994
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.832244   0.897527      0.932994    0.864538  1.000000
# acceleration  0.423329  -0.504683     -0.543800   -0.689196 -0.416839
# model_year    0.580541  -0.345647     -0.369855   -0.416361 -0.309120
# origin        0.565209  -0.568932     -0.614535   -0.455171 -0.585005
#
#               acceleration  model_year    origin
# mpg               0.423329    0.580541  0.565209
# cylinders        -0.504683   -0.345647 -0.568932
# displacement     -0.543800   -0.369855 -0.614535
# horsepower       -0.689196   -0.416361 -0.455171
# weight           -0.416839   -0.309120 -0.585005
# acceleration      1.000000    0.290316  0.212746
# model_year        0.290316    1.000000  0.181528
# origin            0.212746    0.181528  1.000000

# %%
sns.barplot(x="model_year",y="origin",data=ad)
plt.show()

# %%
sns.countplot(x="cylinders",data=ad,hue="model_year")
plt.show()

# %%
plt.violinplot(ad['cylinders'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x2327999e148>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x2327bc55988>,
#  'cmins': <matplotlib.collections.LineCollection at 0x2327bd4d848>,
#  'cbars': <matplotlib.collections.LineCollection at 0x2327bd41f48>}

# %%
sns.pairplot(ad)

# %%
ad.drop(['car_name'],axis = 1,inplace = True)

# %%
ad
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin
# 0            70       1
# 1            70       1
# 2            70       1
# 3            70       1
# 4            70       1
# ..          ...     ...
# 393          82       1
# 394          82       2
# 395          82       1
# 396          82       1
# 397          82       1
#
# [392 rows x 8 columns]

# %%
ad.skew()
# Out:
# mpg             0.457092
# cylinders       0.508109
# displacement    0.701669
# horsepower      1.087326
# weight          0.519586
# acceleration    0.291587
# model_year      0.019688
# origin          0.915185
# dtype: float64

# %%
for index in ad.skew().index:
    if ad.skew().loc[index]>0.5:
        ad[index]=np.log1p(ad[index])

# %%
ad.skew()
# Out:
# mpg             0.457092
# cylinders       0.374305
# displacement    0.214231
# horsepower      0.377557
# weight          0.148665
# acceleration    0.291587
# model_year      0.019688
# origin          0.790401
# dtype: float64

# %%
#removing of outliers
from scipy.stats import zscore
z_score=abs(zscore(ad))
print(ad.shape)
ad_new=ad.loc[(z_score<3).all(axis=1)]
print(ad_new.shape)
# Out:
# (392, 8)
# (390, 8)

# %%
ad_new
# Out:
#       mpg  cylinders  displacement  horsepower    weight  acceleration  \
# 0    18.0   2.197225      5.730100    4.875197  8.161946          12.0
# 1    15.0   2.197225      5.860786    5.111988  8.214465          11.5
# 2    18.0   2.197225      5.765191    5.017280  8.142354          11.0
# 3    16.0   2.197225      5.720312    5.017280  8.141481          12.0
# 4    17.0   2.197225      5.713733    4.948760  8.146130          10.5
# ..    ...        ...           ...         ...       ...           ...
# 392  27.0   1.609438      5.023881    4.510860  7.989899          17.3
# 393  27.0   1.609438      4.948760    4.465908  7.934155          15.6
# 395  32.0   1.609438      4.912655    4.442651  7.738924          11.6
# 396  28.0   1.609438      4.795791    4.382027  7.873217          18.6
# 397  31.0   1.609438      4.787492    4.418841  7.908755          19.4
#
#      model_year    origin
# 0            70  0.693147
# 1            70  0.693147
# 2            70  0.693147
# 3            70  0.693147
# 4            70  0.693147
# ..          ...       ...
# 392          82  0.693147
# 393          82  0.693147
# 395          82  0.693147
# 396          82  0.693147
# 397          82  0.693147
#
# [390 rows x 8 columns]

# %%
#assigning x and y values for training and testing
x=ad.drop(columns=["mpg"])
y=ad[["mpg"]]

# %%
from sklearn.preprocessing import StandardScaler
scx=StandardScaler()
x=scx.fit_transform(x)
x
# Out:
# array([[ 1.42398845,  1.12602885,  0.81453267, ..., -1.285258  ,
#         -1.62531533, -0.73689439],
#        [ 1.42398845,  1.37315636,  1.51191473, ..., -1.46672362,
#         -1.62531533, -0.73689439],
#        [ 1.42398845,  1.19238639,  1.23298616, ..., -1.64818924,
#         -1.62531533, -0.73689439],
#        ...,
#        [-0.88191791, -0.41975602, -0.45937786, ..., -1.4304305 ,
#          1.63640964, -0.73689439],
#        [-0.88191791, -0.640746  , -0.63792611, ...,  1.11008813,
#          1.63640964, -0.73689439],
#        [-0.88191791, -0.656439  , -0.52950365, ...,  1.40043312,
#          1.63640964, -0.73689439]])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
def maxr2_score(regr,x,y):
    max_r_score=0
    for r_state in range(42,100):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.22)
        regr.fit(x_train,y_train)
        y_pred=regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print("maximum r2_score to :",final_r_state," is :",max_r_score)
    return final_r_state

# %%
lregr=LinearRegression()
r_state=maxr2_score(lregr,x,y)
# Out:
# maximum r2_score to : 59  is : 0.8871107931403834

# %%
#checking with decision_tree_classifier
from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor()

# %%
r_state=maxr2_score(dt,x,y)
# Out:
# maximum r2_score to : 50  is : 0.8644800099818801

# %%
#doing cross validation to check whether the model is suffering from overfitting or underfitting
from sklearn.model_selection import cross_val_score
cross_val_score(dt,x,y,cv=5,scoring="r2").mean()
#not suffering from over fitting over under fitting
# Out:
# 0.5540611217041507

# %%
#Using KNeighbors
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV

# %%
neighbors={"n_neighbors":range(1,30)}
knn=KNeighborsRegressor()
grs=GridSearchCV(knn,neighbors,cv=10)
grs.fit(x,y)
grs.best_params_
# Out:
# {'n_neighbors': 6}

# %%
knn=KNeighborsRegressor(n_neighbors=6)
r_state=maxr2_score(knn,x,y)
# Out:
# maximum r2_score to : 88  is : 0.9150542603655973

# %%
#doing cross validation to check whether the model is suffering from overfitting or underfitting
print("Mean r2 score for KNN Regression: ",cross_val_score(knn,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for KNN Regression: ",cross_val_score(knn,x,y,cv=5,scoring="r2").std())
print(cross_val_score(knn,x,y,cv=5,scoring="r2"))
#not suffering from overfitting or underfitting
# Out:
# Mean r2 score for KNN Regression:  0.7126944816495987
# standard deviation in r2 score for KNN Regression:  0.2199396233661736
# [0.84355417 0.86312161 0.81399758 0.76498191 0.27781713]

# %%
#Using SVM model
from sklearn.svm import SVR

# %%
svm=SVR()

# %%
parameters={"kernel":["linear", "poly", "rbf"],"C":[0.001,0.01,0.1]}
grs = GridSearchCV(svm, parameters, cv=10)

# %%
grs.fit(x,y)
# Out:
# GridSearchCV(cv=10, error_score=nan,
#              estimator=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3,
#                            epsilon=0.1, gamma='scale', kernel='rbf',
#                            max_iter=-1, shrinking=True, tol=0.001,
#                            verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'C': [0.001, 0.01, 0.1],
#                          'kernel': ['linear', 'poly', 'rbf']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
grs.best_params_
# Out:
# {'C': 0.1, 'kernel': 'linear'}

# %%
svm=SVR(kernel="linear",C=0.1)
r_state=maxr2_score(svm,x,y)
# Out:
# maximum r2_score to : 59  is : 0.8983476359783245

# %%
#doing cross validation to check whether the model is suffering from overfitting or underfitting
print("Mean r2 score for SVM Regression: ",cross_val_score(svm,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for SVM Regression: ",cross_val_score(svm,x,y,cv=5,scoring="r2").std())
print(cross_val_score(svm,x,y,cv=5,scoring="r2"))
#not suffering from overfitting or underfitting
# Out:
# Mean r2 score for SVM Regression:  0.6300641248937087
# standard deviation in r2 score for SVM Regression:  0.3040138627233495
# [0.75037469 0.79218153 0.85991281 0.71839739 0.02945421]

# %%
#As knn is showing the best results so we will save it for the production
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=88,test_size=0.22)
knn=KNeighborsRegressor(n_neighbors=6)
knn.fit(x_train,y_train)
y_pred=knn.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error
print("r2 score is:" ,r2_score(y_test,y_pred))
print("RMSE is:" ,np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2 score is: 0.9150542603655973
# RMSE is: 2.245969854535905

# %%
#Saving the model
from sklearn.externals import joblib
joblib.dump(knn,'Autompg_knn.pk1')
# Out:
# ['Autompg_knn.pk1']
